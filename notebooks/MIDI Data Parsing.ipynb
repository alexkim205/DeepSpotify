# %%
from music21 import converter, instrument

midi_f = "../data/Movie_Themes_-_2001_-_Also_Sprach_Zarathustra_Richard_Strauss.mid"

midi = converter.parse(midi_f)

midi_parts = instrument.partitionByInstrument(midi)

for instrument in midi_parts.recurse():
    print(instrument)

len(byinstrument)
# Out:
# <music21.stream.Score 0x10576f0b8>
# <music21.stream.Part Piccolo>
# Piccolo
# <music21.tempo.MetronomeMark larghetto Quarter=59.0>
# C major
# C major
# C major
# C major
# C major
# C major
# C major
# C major
# C major
# <music21.meter.TimeSignature 4/4>
# <music21.note.Rest rest>
# <music21.tempo.MetronomeMark adagietto Quarter=67.0>
# <music21.tempo.MetronomeMark adagietto Quarter=64.0>
# <music21.tempo.MetronomeMark adagietto Quarter=64.0>
# <music21.tempo.MetronomeMark Quarter=63.0>
# <music21.tempo.MetronomeMark larghetto Quarter=62.0>
# <music21.tempo.MetronomeMark larghetto Quarter=61.0>
# <music21.tempo.MetronomeMark larghetto Quarter=61.0>
# <music21.tempo.MetronomeMark larghetto Quarter=60.0>
# <music21.tempo.MetronomeMark larghetto Quarter=60.0>
# <music21.tempo.MetronomeMark larghetto Quarter=59.0>
# <music21.tempo.MetronomeMark adagio Quarter=58.0>
# <music21.tempo.MetronomeMark adagio Quarter=58.0>
# <music21.tempo.MetronomeMark adagio Quarter=57.0>
# ...
