# %%
from music21 import converter, instrument

midi_f = "../data/mid/Movie_Themes_-_2001_-_Also_Sprach_Zarathustra_Richard_Strauss.mid"

midi = converter.parse(midi_f)

midi_parts = instrument.partitionByInstrument(midi)

midi_parts.show('text')

#for instrument in midi_parts.recurse():
#    print(instrument)
# Out:
# {0.0} <music21.stream.Part Piccolo>
#     {0.0} <music21.instrument.Piccolo Piccolo>
#     {0.0} <music21.tempo.MetronomeMark larghetto Quarter=59.0>
#     {0.0} <music21.key.Key of C major>
#     {0.0} <music21.key.Key of C major>
#     {0.0} <music21.key.Key of C major>
#     {0.0} <music21.key.Key of C major>
#     {0.0} <music21.key.Key of C major>
#     {0.0} <music21.key.Key of C major>
#     {0.0} <music21.key.Key of C major>
#     {0.0} <music21.key.Key of C major>
#     {0.0} <music21.key.Key of C major>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.note.Rest rest>
#     {11.0} <music21.tempo.MetronomeMark adagietto Quarter=67.0>
#     {16.0} <music21.tempo.MetronomeMark adagietto Quarter=64.0>
#     {16.5} <music21.tempo.MetronomeMark adagietto Quarter=64.0>
#     {16.5} <music21.tempo.MetronomeMark Quarter=63.0>
#     {17.0} <music21.tempo.MetronomeMark larghetto Quarter=62.0>
#     {17.0} <music21.tempo.MetronomeMark larghetto Quarter=61.0>
# ...
